# %% [markdown]
# <a href="https://colab.research.google.com/github/S10955013/bigdata/blob/main/0316_%E4%BD%9C%E6%A5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#列印出檔案
system("ls",TRUE)

#載入reader套件
library(readr)

#讀取.csv檔案
dataset <- read.csv("20210316.csv") #dataset:變數名稱

#印出dataset
dataset
# Out:
# [1] "20210316.csv" "sample_data"
#    廠商名稱                                   聯絡電話
# 1  宜蘭渡小月餐廳有限公司                     03-9324414
# 2  金樽廣場（宜蘭店）                         03-9389929
# 3  口香亭飲食店                               03-9329078
# 4  千藝創意料理海鮮餐廳(千藝食堂餐廳有限公司) 03-9315878
# 5  地中海餐廳                                 03-9305000
# 6  歐遊國際有限公司宜蘭分公司                 03-9281133
# 7  悅川酒店(羅琳西餐廳)                       03-9699333
# 8  涓豆腐(宜蘭新月店)                         03-9363288
# 9  TASTY西堤牛排(宜蘭新月店)                  03-9312725
# 10 古拉爵(宜蘭新月廣場店)                     03-9314810
# 11 瓦城(宜蘭新月店)                           03-9315522
# 12 金宴翔餐廳                                 03-9326628
# 13 勝博殿(宜蘭店)                             03-9367398
# 14 煙嵐大飯店有限公司                         03-9256899
# 15 爭鮮迴轉壽司(宜蘭店）                      03-9314476
# 16 鬥炙牛排                                   03-9360202
# 17 清原芋圓(宜大店)                           03-9312222
# 18 爭鮮迴轉壽司(羅東店)                       03-9558469
# ...

# %%
#預覽前10筆
head(dataset$廠商名稱, n=10)
# Out:
#  [1] "宜蘭渡小月餐廳有限公司"
#  [2] "金樽廣場（宜蘭店）"
#  [3] "口香亭飲食店"
#  [4] "千藝創意料理海鮮餐廳(千藝食堂餐廳有限公司)"
#  [5] "地中海餐廳"
#  [6] "歐遊國際有限公司宜蘭分公司"
#  [7] "悅川酒店(羅琳西餐廳)"
#  [8] "涓豆腐(宜蘭新月店)"
#  [9] "TASTY西堤牛排(宜蘭新月店)"
# [10] "古拉爵(宜蘭新月廣場店)"

# %%
#預覽後10筆
tail(dataset$廠商名稱, n=10)
# Out:
#  [1] "蘭陽美饌-香料皇廚(蘇澳服務區)" "富美食堂21(蘇澳服務區)"
#  [3] "悟饕(蘇澳服務區店)"            "合盈開發興業有限公司"
#  [5] "手路菜中餐廳"                  "來來來牛排館"
#  [7] "欣瓏徠海鮮餐廳"                "龍之園餐廳"
#  [9] "香格里拉冬山河旅館有限公司"    "中天大飯店-樂沛西餐廳"

# %%
#搜尋 牛排
dataset[grepl("牛排",dataset$廠商名稱),]
# Out:
#    廠商名稱                  聯絡電話   通訊地址
# 9  TASTY西堤牛排(宜蘭新月店) 03-9312725 宜蘭縣宜蘭市民權路二段38巷6號4樓
# 16 鬥炙牛排                  03-9360202 宜蘭縣宜蘭市聖後街11號
# 62 來來來牛排館              03-9507419 宜蘭縣五結鄉親河路二段157號
#    評核結果
# 9  優
# 16 優
# 62 優

# %%
#搜尋 海鮮
dataset[grepl("海鮮",dataset$廠商名稱),]
# Out:
#    廠商名稱                                   聯絡電話
# 4  千藝創意料理海鮮餐廳(千藝食堂餐廳有限公司) 03-9315878
# 50 海底園活海鮮                               03-9967989
# 51 富美活海鮮                                 03-9962807
# 52 上淳活海鮮                                 0910-955137
# 53 正宗豆腐岬活海鮮餐廳                       03-9055767
# 63 欣瓏徠海鮮餐廳                             03-9502018
#    通訊地址                     評核結果
# 4  宜蘭縣宜蘭市校舍路28號       良
# 50 宜蘭縣蘇澳鎮漁港路92號1、2樓 優
# 51 宜蘭縣蘇澳鎮海邊路111號      優
# 52 宜蘭縣蘇澳鎮蘇花路5段106號   良
# 53 宜蘭縣蘇澳鎮蘇東北路2-57號   良
# 63 宜蘭縣五結鄉親河路二段236號  優

# %%
#計算 評核結果
table(dataset$評核結果)
# Out:
# 優 良
# 54 12
